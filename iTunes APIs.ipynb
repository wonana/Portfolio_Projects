# %%
import requests

# %%
import json

# %%
base_site = base_site = "https://itunes.apple.com/search"
url = base_site + "?term=방탄소년단&country=kr"
requests.get(url)

r = requests.get(base_site, params = {"term": "방탄소년단", "country": "kr"})
r.status_code
# Out:
# 200

# %%
info = r.json()
print(json.dumps(info, indent=4))
# Out:
# {
#     "resultCount": 50,
#     "results": [
#         {
#             "wrapperType": "track",
#             "kind": "podcast",
#             "collectionId": 1355412486,
#             "trackId": 1355412486,
#             "artistName": "\ubf40\uc0ac\ub9ac \ucc10",
#             "collectionName": "\uc778\uc0ac\uc774\ud2b8 \ubc14\uc774 \ubc29\ud0c4\uc18c\ub144\ub2e8(Insight by BTS)",
#             "trackName": "\uc778\uc0ac\uc774\ud2b8 \ubc14\uc774 \ubc29\ud0c4\uc18c\ub144\ub2e8(Insight by BTS)",
#             "collectionCensoredName": "\uc778\uc0ac\uc774\ud2b8 \ubc14\uc774 \ubc29\ud0c4\uc18c\ub144\ub2e8(Insight by BTS)",
#             "trackCensoredName": "\uc778\uc0ac\uc774\ud2b8 \ubc14\uc774 \ubc29\ud0c4\uc18c\ub144\ub2e8(Insight by BTS)",
#             "collectionViewUrl": "https://podcasts.apple.com/kr/podcast/%EC%9D%B8%EC%82%AC%EC%9D%B4%ED%8A%B8-%EB%B0%94%EC%9D%B4-%EB%B0%A9%ED%83%84%EC%86%8C%EB%85%84%EB%8B%A8-insight-by-bts/id1355412486?uo=4",
# ...

# %%
info.keys()
# Out:
# dict_keys(['resultCount', 'results'])

# %%
r = requests.get(base_site, params = {"term": "방탄소년단", "country": "kr", "limit": 200, "media":"music"})
r.ok
# Out:
# True

# %%
info = r.json()
info
# Out:
# {'resultCount': 200,
#  'results': [{'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 1368733420,
#    'collectionId': 1600580338,
#    'trackId': 1600581360,
#    'artistName': 'Juice WRLD, SUGA & 방탄소년단',
#    'collectionName': 'Fighting Demons (Lyric Video Version)',
#    'trackName': 'Girl Of My Dreams',
#    'collectionCensoredName': 'Fighting Demons (Lyric Video Version)',
#    'trackCensoredName': 'Girl Of My Dreams',
#    'collectionArtistName': 'Juice WRLD',
#    'artistViewUrl': 'https://music.apple.com/kr/artist/juice-wrld/1368733420?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/kr/album/girl-of-my-dreams/1600580338?i=1600581360&uo=4',
#    'trackViewUrl': 'https://music.apple.com/kr/album/girl-of-my-dreams/1600580338?i=1600581360&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview126/v4/b6/1b/51/b61b51be-fccd-861e-06d5-05ee10dfdc42/mzaf_10282376701104174986.plus.aac.p.m4a',
# ...

# %%
import pandas as pd

# %%
song_df = pd.DataFrame(info["results"])
song_df
# Out:
#     wrapperType  kind    artistId  collectionId     trackId  \
# 0         track  song  1368733420    1600580338  1600581360
# 1         track  song   324916925    1479627997  1479628352
# 2         track  song   324916925    1525309582  1525309584
# 3         track  song   324916925    1533014923  1533014942
# 4         track  song   324916925    1481418637  1481418650
# ..          ...   ...         ...           ...         ...
# 195       track  song   883131348    1598730614  1598730618
# 196       track  song   883131348    1551723290  1551723770
# 197       track  song   883131348    1597016869  1597017066
# 198       track  song   883131348    1596529064  1596529066
# 199       track  song   883131348    1573645075  1573645082
#
#                    artistName                         collectionName  \
# 0    Juice WRLD, SUGA & 방탄소년단  Fighting Demons (Lyric Video Version)
# 1        Halsey, SUGA & 방탄소년단                                  Manic
# ...
